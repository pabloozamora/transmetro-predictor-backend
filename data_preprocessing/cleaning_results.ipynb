# %%
# Obtener el resumen de viajes antes de la limpieza de datos
# de /clean_data/{unit}/{unit}_pre_trips_summary.csv

import pandas as pd
import os
import sys
from pathlib import Path

# Obtener el resumen de viajes antes de la limpieza de datos
# de /joined_data/{unit}/{unit}_joined.csv
def get_pre_trips_summary(unit):
    file_path = Path(f"D:/2025/UVG/Tesis/repos/backend/joined_data/{unit}_joined.csv")
    if not file_path.exists():
        print(f"El archivo {file_path} no existe.")
        sys.exit(1)

    df = pd.read_csv(file_path)
    number_of_rows = df.shape[0]
    print(f"Unidad: {unit}, Número de filas antes de limpieza: {number_of_rows}")
    return number_of_rows

# %%
JOINED_DATA = Path("D:/2025/UVG/Tesis/repos/backend/joined_data")
if not JOINED_DATA.exists():
    print(f"No existe el directorio {JOINED_DATA}. Fin.")
units = [d.name.split("_")[0] for d in JOINED_DATA.iterdir()]

if not units:
    print(f"No se encontraron unidades en {JOINED_DATA}. Fin.")
    
total_rows = 0
for unit in units:
    total_rows += get_pre_trips_summary(unit)
    
print(f"Número total de filas antes de limpieza: {total_rows}")
# Out:
# Unidad: u049, Número de filas antes de limpieza: 226541
# Unidad: u050, Número de filas antes de limpieza: 7989
# Unidad: u051, Número de filas antes de limpieza: 113470
# Unidad: u052, Número de filas antes de limpieza: 46394
# Unidad: u053, Número de filas antes de limpieza: 81276
# Unidad: u055, Número de filas antes de limpieza: 137414
# Unidad: u056, Número de filas antes de limpieza: 135802
# Unidad: u057, Número de filas antes de limpieza: 209848
# Unidad: u058, Número de filas antes de limpieza: 1765
# Unidad: u059, Número de filas antes de limpieza: 308320
# Unidad: u060, Número de filas antes de limpieza: 28904
# Unidad: u061, Número de filas antes de limpieza: 4647
# Unidad: u062, Número de filas antes de limpieza: 247905
# Unidad: u063, Número de filas antes de limpieza: 306084
# Unidad: u064, Número de filas antes de limpieza: 409120
# Unidad: u066, Número de filas antes de limpieza: 187935
# Unidad: u067, Número de filas antes de limpieza: 347426
# Unidad: u068, Número de filas antes de limpieza: 411482
# Unidad: u069, Número de filas antes de limpieza: 309131
# Unidad: u070, Número de filas antes de limpieza: 319548
# Unidad: u071, Número de filas antes de limpieza: 521217
# Unidad: u074, Número de filas antes de limpieza: 420897
# Unidad: u075, Número de filas antes de limpieza: 25257
# Unidad: u086, Número de filas antes de limpieza: 754614
# Unidad: u087, Número de filas antes de limpieza: 479373
# Unidad: u088, Número de filas antes de limpieza: 439225
# Unidad: u089, Número de filas antes de limpieza: 426816
# Unidad: u090, Número de filas antes de limpieza: 584140
# Unidad: u091, Número de filas antes de limpieza: 369368
# Unidad: u092, Número de filas antes de limpieza: 472414
# Unidad: u093, Número de filas antes de limpieza: 587468
# Unidad: u094, Número de filas antes de limpieza: 550247
# Unidad: u095, Número de filas antes de limpieza: 603296
# Unidad: u096, Número de filas antes de limpieza: 594341
# Unidad: u097, Número de filas antes de limpieza: 225233
# Unidad: u098, Número de filas antes de limpieza: 566250
# Unidad: u099, Número de filas antes de limpieza: 543513
# Unidad: u100, Número de filas antes de limpieza: 539438
# Unidad: u101, Número de filas antes de limpieza: 582990
# Unidad: u102, Número de filas antes de limpieza: 419914
# Unidad: u104, Número de filas antes de limpieza: 1304
# Unidad: u105, Número de filas antes de limpieza: 275613
# Unidad: u106, Número de filas antes de limpieza: 478565
# Unidad: u107, Número de filas antes de limpieza: 433639
# Unidad: u110, Número de filas antes de limpieza: 574239
# Unidad: u111, Número de filas antes de limpieza: 437663
# Unidad: u112, Número de filas antes de limpieza: 569416
# Unidad: u113, Número de filas antes de limpieza: 485594
# Unidad: u114, Número de filas antes de limpieza: 435048
# Unidad: u115, Número de filas antes de limpieza: 393999
# Unidad: u116, Número de filas antes de limpieza: 291330
# Unidad: u117, Número de filas antes de limpieza: 534060
# Unidad: u118, Número de filas antes de limpieza: 519140
# Unidad: u119, Número de filas antes de limpieza: 123921
# Unidad: u120, Número de filas antes de limpieza: 449499
# Unidad: u121, Número de filas antes de limpieza: 439882
# Unidad: u122, Número de filas antes de limpieza: 574286
# Unidad: u123, Número de filas antes de limpieza: 481516
# Unidad: u124, Número de filas antes de limpieza: 581147
# Unidad: u125, Número de filas antes de limpieza: 588033
# Unidad: u127, Número de filas antes de limpieza: 565810
# Unidad: u128, Número de filas antes de limpieza: 476430
# Unidad: u129, Número de filas antes de limpieza: 460612
# Unidad: u130, Número de filas antes de limpieza: 522859
# Unidad: u131, Número de filas antes de limpieza: 483701
# Unidad: u132, Número de filas antes de limpieza: 514455
# Unidad: u133, Número de filas antes de limpieza: 186800
# Unidad: u134, Número de filas antes de limpieza: 533327
# Unidad: u135, Número de filas antes de limpieza: 556674
# Unidad: u136, Número de filas antes de limpieza: 331160
# Unidad: u137, Número de filas antes de limpieza: 671136
# Unidad: u138, Número de filas antes de limpieza: 507766
# Unidad: u139, Número de filas antes de limpieza: 523911
# Unidad: u140, Número de filas antes de limpieza: 629064
# Unidad: u141, Número de filas antes de limpieza: 336390
# Unidad: u142, Número de filas antes de limpieza: 528464
# Unidad: u144, Número de filas antes de limpieza: 518645
# Unidad: u145, Número de filas antes de limpieza: 504229
# Unidad: u146, Número de filas antes de limpieza: 530819
# Unidad: u148, Número de filas antes de limpieza: 510772
# Unidad: u149, Número de filas antes de limpieza: 549046
# Unidad: u150, Número de filas antes de limpieza: 554277
# Unidad: u151, Número de filas antes de limpieza: 566398
# Unidad: u152, Número de filas antes de limpieza: 324048
# Unidad: u153, Número de filas antes de limpieza: 532375
# Unidad: u154, Número de filas antes de limpieza: 722947
# Unidad: u155, Número de filas antes de limpieza: 539686
# Unidad: u156, Número de filas antes de limpieza: 563924
# Unidad: u157, Número de filas antes de limpieza: 509460
# Unidad: u158, Número de filas antes de limpieza: 547040
# Unidad: u159, Número de filas antes de limpieza: 392739
# Unidad: u160, Número de filas antes de limpieza: 482493
# Unidad: u161, Número de filas antes de limpieza: 576917
# Unidad: u201, Número de filas antes de limpieza: 426506
# Unidad: u203, Número de filas antes de limpieza: 402788
# Unidad: u204, Número de filas antes de limpieza: 422441
# Unidad: u205, Número de filas antes de limpieza: 390741
# Unidad: u206, Número de filas antes de limpieza: 412425
# Unidad: u207, Número de filas antes de limpieza: 409508
# Unidad: u208, Número de filas antes de limpieza: 416452
# Unidad: u210, Número de filas antes de limpieza: 415947
# Unidad: u211, Número de filas antes de limpieza: 423607
# Unidad: u212, Número de filas antes de limpieza: 444453
# Unidad: u213, Número de filas antes de limpieza: 335910
# Unidad: u214, Número de filas antes de limpieza: 405297
# Unidad: u215, Número de filas antes de limpieza: 148646
# Unidad: u216, Número de filas antes de limpieza: 457257
# Unidad: u217, Número de filas antes de limpieza: 94662
# Unidad: u218, Número de filas antes de limpieza: 519645
# Unidad: u219, Número de filas antes de limpieza: 164558
# Unidad: u220, Número de filas antes de limpieza: 471659
# Unidad: u221, Número de filas antes de limpieza: 410795
# Unidad: u222, Número de filas antes de limpieza: 409255
# Unidad: u223, Número de filas antes de limpieza: 455780
# Unidad: u224, Número de filas antes de limpieza: 435521
# Unidad: u225, Número de filas antes de limpieza: 387408
# Unidad: u226, Número de filas antes de limpieza: 447910
# Unidad: u227, Número de filas antes de limpieza: 441743
# Unidad: u228, Número de filas antes de limpieza: 396336
# Unidad: u231, Número de filas antes de limpieza: 432452
# Unidad: u232, Número de filas antes de limpieza: 138662
# Unidad: u233, Número de filas antes de limpieza: 393319
# Unidad: u234, Número de filas antes de limpieza: 430732
# Unidad: u235, Número de filas antes de limpieza: 218032
# Unidad: u236, Número de filas antes de limpieza: 391857
# Unidad: u237, Número de filas antes de limpieza: 417161
# Unidad: u238, Número de filas antes de limpieza: 415961
# Unidad: u239, Número de filas antes de limpieza: 432981
# Unidad: u240, Número de filas antes de limpieza: 399494
# Unidad: u241, Número de filas antes de limpieza: 337269
# Unidad: u242, Número de filas antes de limpieza: 407622
# Unidad: u301, Número de filas antes de limpieza: 425091
# Unidad: u302, Número de filas antes de limpieza: 473796
# Unidad: u303, Número de filas antes de limpieza: 467499
# Unidad: u304, Número de filas antes de limpieza: 404574
# Unidad: u305, Número de filas antes de limpieza: 420318
# Unidad: u306, Número de filas antes de limpieza: 462663
# Unidad: u307, Número de filas antes de limpieza: 326911
# Unidad: u308, Número de filas antes de limpieza: 454428
# Unidad: u309, Número de filas antes de limpieza: 421726
# Unidad: u310, Número de filas antes de limpieza: 291490
# Unidad: u401, Número de filas antes de limpieza: 343433
# Unidad: u402, Número de filas antes de limpieza: 332481
# Unidad: uBC232, Número de filas antes de limpieza: 38719
# Unidad: uBC322, Número de filas antes de limpieza: 39238
# Unidad: uBC478, Número de filas antes de limpieza: 5674
# Unidad: uBC484, Número de filas antes de limpieza: 3668
# Unidad: uBI002, Número de filas antes de limpieza: 318357
# Unidad: uBI003, Número de filas antes de limpieza: 328434
# Unidad: uBI004, Número de filas antes de limpieza: 775665
# Unidad: uBI005, Número de filas antes de limpieza: 508536
# Unidad: uBI006, Número de filas antes de limpieza: 396650
# Unidad: uBI007, Número de filas antes de limpieza: 346562
# Unidad: uBI008, Número de filas antes de limpieza: 357663
# Unidad: uBI009, Número de filas antes de limpieza: 378303
# Unidad: uBI010, Número de filas antes de limpieza: 345546
# Unidad: uBI011, Número de filas antes de limpieza: 365190
# Unidad: uBI012, Número de filas antes de limpieza: 349664
# Unidad: uBI013, Número de filas antes de limpieza: 343083
# Número total de filas antes de limpieza: 63257434

# %%
# Número total de filas después de la limpieza de datos
CLEAN_DATA_DIR = Path("D:/2025/UVG/Tesis/repos/backend/clean_data")
if not CLEAN_DATA_DIR.exists():
    print(f"No existe el directorio {CLEAN_DATA_DIR}. Fin.")
units = [p.name for p in CLEAN_DATA_DIR.iterdir() if p.is_dir() and p.name != "maps"]
if not units:
    print(f"No se encontraron unidades en {CLEAN_DATA_DIR}. Fin.")
    
total_useful_units = 0
total_cleaned_rows = 0
for unit in units:
    summary_file = CLEAN_DATA_DIR / unit / f"{unit}_post_trips_summary.csv"
    if not summary_file.exists():
        print(f"El archivo {summary_file} no existe. Saltando unidad {unit}.")
        continue
    df_summary = pd.read_csv(summary_file)
    cleaned_rows = df_summary['puntos'].sum()
    total_cleaned_rows += cleaned_rows
    print(f"Unidad: {unit}, Número de filas después de limpieza: {cleaned_rows}")
    if cleaned_rows > 0:
        total_useful_units += 1
        
print(f"Número total de filas después de limpieza: {total_cleaned_rows}")
print(f"Número total de unidades útiles después de limpieza: {total_useful_units}")
# Out:
# Unidad: u049, Número de filas después de limpieza: 118834
# Unidad: u050, Número de filas después de limpieza: 5495
# Unidad: u051, Número de filas después de limpieza: 56810
# Unidad: u052, Número de filas después de limpieza: 15551
# Unidad: u053, Número de filas después de limpieza: 63514
# Unidad: u055, Número de filas después de limpieza: 89552
# Unidad: u056, Número de filas después de limpieza: 89627
# Unidad: u057, Número de filas después de limpieza: 92598
# Unidad: u058, Número de filas después de limpieza: 0
# Unidad: u059, Número de filas después de limpieza: 194050
# Unidad: u060, Número de filas después de limpieza: 15990
# Unidad: u061, Número de filas después de limpieza: 100
# Unidad: u062, Número de filas después de limpieza: 101079
# Unidad: u063, Número de filas después de limpieza: 162224
# Unidad: u064, Número de filas después de limpieza: 264044
# Unidad: u066, Número de filas después de limpieza: 133345
# Unidad: u067, Número de filas después de limpieza: 225324
# Unidad: u068, Número de filas después de limpieza: 306530
# Unidad: u069, Número de filas después de limpieza: 129813
# Unidad: u070, Número de filas después de limpieza: 203396
# Unidad: u071, Número de filas después de limpieza: 389387
# Unidad: u074, Número de filas después de limpieza: 311744
# Unidad: u075, Número de filas después de limpieza: 9403
# Unidad: u086, Número de filas después de limpieza: 655480
# Unidad: u087, Número de filas después de limpieza: 434838
# Unidad: u088, Número de filas después de limpieza: 324569
# Unidad: u089, Número de filas después de limpieza: 304742
# Unidad: u090, Número de filas después de limpieza: 475601
# Unidad: u091, Número de filas después de limpieza: 284001
# Unidad: u092, Número de filas después de limpieza: 384328
# Unidad: u093, Número de filas después de limpieza: 494462
# Unidad: u094, Número de filas después de limpieza: 454245
# Unidad: u095, Número de filas después de limpieza: 515137
# Unidad: u096, Número de filas después de limpieza: 502177
# Unidad: u097, Número de filas después de limpieza: 138897
# Unidad: u098, Número de filas después de limpieza: 469214
# Unidad: u099, Número de filas después de limpieza: 434321
# Unidad: u100, Número de filas después de limpieza: 432726
# Unidad: u101, Número de filas después de limpieza: 495269
# Unidad: u102, Número de filas después de limpieza: 314843
# Unidad: u104, Número de filas después de limpieza: 1001
# Unidad: u105, Número de filas después de limpieza: 160750
# Unidad: u106, Número de filas después de limpieza: 423661
# Unidad: u107, Número de filas después de limpieza: 333059
# Unidad: u110, Número de filas después de limpieza: 466270
# Unidad: u111, Número de filas después de limpieza: 325938
# Unidad: u112, Número de filas después de limpieza: 480495
# Unidad: u113, Número de filas después de limpieza: 373970
# Unidad: u114, Número de filas después de limpieza: 334718
# Unidad: u115, Número de filas después de limpieza: 306512
# Unidad: u116, Número de filas después de limpieza: 214027
# Unidad: u117, Número de filas después de limpieza: 438443
# Unidad: u118, Número de filas después de limpieza: 417341
# Unidad: u119, Número de filas después de limpieza: 58489
# Unidad: u120, Número de filas después de limpieza: 339503
# Unidad: u121, Número de filas después de limpieza: 360439
# Unidad: u122, Número de filas después de limpieza: 459250
# Unidad: u123, Número de filas después de limpieza: 378026
# Unidad: u124, Número de filas después de limpieza: 472459
# Unidad: u125, Número de filas después de limpieza: 469830
# Unidad: u127, Número de filas después de limpieza: 441229
# Unidad: u128, Número de filas después de limpieza: 345687
# Unidad: u129, Número de filas después de limpieza: 361253
# Unidad: u130, Número de filas después de limpieza: 417072
# Unidad: u131, Número de filas después de limpieza: 378591
# Unidad: u132, Número de filas después de limpieza: 416491
# Unidad: u133, Número de filas después de limpieza: 147659
# Unidad: u134, Número de filas después de limpieza: 426173
# Unidad: u135, Número de filas después de limpieza: 450362
# Unidad: u136, Número de filas después de limpieza: 261405
# Unidad: u137, Número de filas después de limpieza: 553370
# Unidad: u138, Número de filas después de limpieza: 411356
# Unidad: u139, Número de filas después de limpieza: 407966
# Unidad: u140, Número de filas después de limpieza: 520908
# Unidad: u141, Número de filas después de limpieza: 269128
# Unidad: u142, Número de filas después de limpieza: 421781
# Unidad: u144, Número de filas después de limpieza: 419486
# Unidad: u145, Número de filas después de limpieza: 395505
# Unidad: u146, Número de filas después de limpieza: 417090
# Unidad: u148, Número de filas después de limpieza: 411036
# Unidad: u149, Número de filas después de limpieza: 435652
# Unidad: u150, Número de filas después de limpieza: 454223
# Unidad: u151, Número de filas después de limpieza: 450938
# Unidad: u152, Número de filas después de limpieza: 283628
# Unidad: u153, Número de filas después de limpieza: 432900
# Unidad: u154, Número de filas después de limpieza: 612229
# Unidad: u155, Número de filas después de limpieza: 440624
# Unidad: u156, Número de filas después de limpieza: 458229
# Unidad: u157, Número de filas después de limpieza: 432936
# Unidad: u158, Número de filas después de limpieza: 453449
# Unidad: u159, Número de filas después de limpieza: 317126
# Unidad: u160, Número de filas después de limpieza: 385033
# Unidad: u161, Número de filas después de limpieza: 475190
# Unidad: u201, Número de filas después de limpieza: 384460
# Unidad: u203, Número de filas después de limpieza: 361945
# Unidad: u204, Número de filas después de limpieza: 384663
# Unidad: u205, Número de filas después de limpieza: 349558
# Unidad: u206, Número de filas después de limpieza: 366428
# Unidad: u207, Número de filas después de limpieza: 365856
# Unidad: u208, Número de filas después de limpieza: 379603
# Unidad: u210, Número de filas después de limpieza: 371620
# Unidad: u211, Número de filas después de limpieza: 379608
# Unidad: u212, Número de filas después de limpieza: 407366
# Unidad: u213, Número de filas después de limpieza: 296215
# Unidad: u214, Número de filas después de limpieza: 359491
# Unidad: u215, Número de filas después de limpieza: 131872
# Unidad: u216, Número de filas después de limpieza: 414979
# Unidad: u217, Número de filas después de limpieza: 84462
# Unidad: u218, Número de filas después de limpieza: 471709
# Unidad: u219, Número de filas después de limpieza: 147802
# Unidad: u220, Número de filas después de limpieza: 377132
# Unidad: u221, Número de filas después de limpieza: 368522
# Unidad: u222, Número de filas después de limpieza: 366865
# Unidad: u223, Número de filas después de limpieza: 394772
# Unidad: u224, Número de filas después de limpieza: 394848
# Unidad: u225, Número de filas después de limpieza: 353772
# Unidad: u226, Número de filas después de limpieza: 404076
# Unidad: u227, Número de filas después de limpieza: 363232
# Unidad: u228, Número de filas después de limpieza: 355651
# Unidad: u231, Número de filas después de limpieza: 397800
# Unidad: u232, Número de filas después de limpieza: 67411
# Unidad: u233, Número de filas después de limpieza: 347024
# Unidad: u234, Número de filas después de limpieza: 385667
# Unidad: u235, Número de filas después de limpieza: 175439
# Unidad: u236, Número de filas después de limpieza: 350188
# Unidad: u237, Número de filas después de limpieza: 365390
# Unidad: u238, Número de filas después de limpieza: 370613
# Unidad: u239, Número de filas después de limpieza: 386968
# Unidad: u240, Número de filas después de limpieza: 352223
# Unidad: u241, Número de filas después de limpieza: 254688
# Unidad: u242, Número de filas después de limpieza: 371684
# Unidad: u301, Número de filas después de limpieza: 392274
# Unidad: u302, Número de filas después de limpieza: 425838
# Unidad: u303, Número de filas después de limpieza: 425197
# Unidad: u304, Número de filas después de limpieza: 366074
# Unidad: u305, Número de filas después de limpieza: 380356
# Unidad: u306, Número de filas después de limpieza: 428832
# Unidad: u307, Número de filas después de limpieza: 286672
# Unidad: u308, Número de filas después de limpieza: 409205
# Unidad: u309, Número de filas después de limpieza: 377653
# Unidad: u310, Número de filas después de limpieza: 259905
# Unidad: u401, Número de filas después de limpieza: 297877
# Unidad: u402, Número de filas después de limpieza: 301127
# Unidad: uBC232, Número de filas después de limpieza: 1794
# Unidad: uBC322, Número de filas después de limpieza: 8557
# Unidad: uBC478, Número de filas después de limpieza: 0
# Unidad: uBC484, Número de filas después de limpieza: 0
# Unidad: uBI002, Número de filas después de limpieza: 235479
# Unidad: uBI003, Número de filas después de limpieza: 236143
# Unidad: uBI004, Número de filas después de limpieza: 619794
# Unidad: uBI005, Número de filas después de limpieza: 399733
# Unidad: uBI006, Número de filas después de limpieza: 294567
# Unidad: uBI007, Número de filas después de limpieza: 252873
# Unidad: uBI008, Número de filas después de limpieza: 283777
# Unidad: uBI009, Número de filas después de limpieza: 279179
# Unidad: uBI010, Número de filas después de limpieza: 253265
# Unidad: uBI011, Número de filas después de limpieza: 268858
# Unidad: uBI012, Número de filas después de limpieza: 253123
# Unidad: uBI013, Número de filas después de limpieza: 248206
# Número total de filas después de limpieza: 51261106
# Número total de unidades útiles después de limpieza: 156

# %%
# Número total de filas después de la ingeniería de características
FEATURES_READY_DIR = Path("D:/2025/UVG/Tesis/repos/backend/features_ready_without_idle_rows")
if not FEATURES_READY_DIR.exists():
    print(f"No existe el directorio {FEATURES_READY_DIR}. Fin.")
feature_files = list(FEATURES_READY_DIR.glob("*.parquet"))
if not feature_files:
    print(f"No se encontraron archivos de características en {FEATURES_READY_DIR}. Fin.")
total_featured_rows = 0
total_useful_units = 0
for feature_file in feature_files:
    df_features = pd.read_parquet(feature_file)
    featured_rows = df_features.shape[0]
    total_featured_rows += featured_rows
    total_useful_units += 1
    print(f"Archivo: {feature_file.name}, Número de filas después de ingeniería de características: {featured_rows}")
print(f"Número total de filas después de ingeniería de características: {total_featured_rows}")
print(f"Número total de unidades útiles: {total_useful_units}")
# Out:
# Archivo: u049_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 98584
# Archivo: u050_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 4992
# Archivo: u051_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 48946
# Archivo: u052_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 13079
# Archivo: u053_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 58236
# Archivo: u055_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 76797
# Archivo: u056_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 76769
# Archivo: u057_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 77778
# Archivo: u059_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 169648
# Archivo: u060_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 13789
# Archivo: u061_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 64
# Archivo: u062_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 78120
# Archivo: u063_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 142577
# Archivo: u064_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 233190
# Archivo: u066_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 102232
# Archivo: u067_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 180455
# Archivo: u068_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 231103
# Archivo: u069_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 91054
# Archivo: u070_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 156000
# Archivo: u071_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 289232
# Archivo: u074_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 202903
# Archivo: u075_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 8155
# Archivo: u086_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 530889
# Archivo: u087_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 306747
# Archivo: u088_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 265927
# Archivo: u089_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 247749
# Archivo: u090_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 372708
# Archivo: u091_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 212882
# Archivo: u092_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 300479
# Archivo: u093_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 409461
# Archivo: u094_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 342810
# Archivo: u095_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 393106
# Archivo: u096_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 392037
# Archivo: u097_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 102658
# Archivo: u098_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 353273
# Archivo: u099_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 341291
# Archivo: u100_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 343876
# Archivo: u101_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 371549
# Archivo: u102_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 240800
# Archivo: u104_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 892
# Archivo: u105_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 133472
# Archivo: u106_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 327268
# Archivo: u107_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 257879
# Archivo: u110_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 377207
# Archivo: u111_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 247005
# Archivo: u112_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 361853
# Archivo: u113_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 308171
# Archivo: u114_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 286494
# Archivo: u115_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 251464
# Archivo: u116_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 178515
# Archivo: u117_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 362495
# Archivo: u118_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 360044
# Archivo: u119_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 32698
# Archivo: u120_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 304711
# Archivo: u121_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 326787
# Archivo: u122_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 399747
# Archivo: u123_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 316996
# Archivo: u124_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 414429
# Archivo: u125_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 415904
# Archivo: u127_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 393377
# Archivo: u128_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 309140
# Archivo: u129_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 319213
# Archivo: u130_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 363057
# Archivo: u131_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 319835
# Archivo: u132_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 356182
# Archivo: u133_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 127591
# Archivo: u134_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 362925
# Archivo: u135_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 398635
# Archivo: u136_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 222476
# Archivo: u137_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 500323
# Archivo: u138_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 357405
# Archivo: u139_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 348262
# Archivo: u140_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 461718
# Archivo: u141_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 215161
# Archivo: u142_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 369688
# Archivo: u144_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 365196
# Archivo: u145_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 350756
# Archivo: u146_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 360977
# Archivo: u148_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 358831
# Archivo: u149_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 384690
# Archivo: u150_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 397884
# Archivo: u151_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 398795
# Archivo: u152_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 218582
# Archivo: u153_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 386856
# Archivo: u154_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 543669
# Archivo: u155_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 393192
# Archivo: u156_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 408673
# Archivo: u157_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 393184
# Archivo: u158_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 405691
# Archivo: u159_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 283123
# Archivo: u160_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 344514
# Archivo: u161_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 425952
# Archivo: u201_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 325956
# Archivo: u203_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 302847
# Archivo: u204_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 322124
# Archivo: u205_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 299057
# Archivo: u206_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 312117
# Archivo: u207_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 309908
# Archivo: u208_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 328922
# Archivo: u210_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 314591
# Archivo: u211_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 323621
# Archivo: u212_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 348016
# Archivo: u213_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 243919
# Archivo: u214_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 304208
# Archivo: u215_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 112176
# Archivo: u216_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 349504
# Archivo: u217_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 71909
# Archivo: u218_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 408693
# Archivo: u219_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 128228
# Archivo: u220_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 318936
# Archivo: u221_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 310524
# Archivo: u222_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 316085
# Archivo: u223_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 336718
# Archivo: u224_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 335156
# Archivo: u225_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 303834
# Archivo: u226_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 342970
# Archivo: u227_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 306981
# Archivo: u228_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 303852
# Archivo: u231_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 343807
# Archivo: u232_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 44905
# Archivo: u233_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 286892
# Archivo: u234_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 322215
# Archivo: u235_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 149366
# Archivo: u236_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 294414
# Archivo: u237_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 311004
# Archivo: u238_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 311350
# Archivo: u239_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 326221
# Archivo: u240_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 297001
# Archivo: u241_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 215817
# Archivo: u242_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 323530
# Archivo: u301_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 345106
# Archivo: u302_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 371231
# Archivo: u303_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 369761
# Archivo: u304_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 322503
# Archivo: u305_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 331368
# Archivo: u306_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 376975
# Archivo: u307_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 251192
# Archivo: u308_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 356637
# Archivo: u309_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 327537
# Archivo: u310_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 225431
# Archivo: u401_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 253340
# Archivo: u402_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 253537
# Archivo: uBC232_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 980
# Archivo: uBC322_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 5389
# Archivo: uBI002_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 212686
# Archivo: uBI003_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 176543
# Archivo: uBI004_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 574520
# Archivo: uBI005_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 323850
# Archivo: uBI006_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 231728
# Archivo: uBI007_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 189188
# Archivo: uBI008_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 233290
# Archivo: uBI009_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 214048
# Archivo: uBI010_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 192648
# Archivo: uBI011_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 207743
# Archivo: uBI012_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 196083
# Archivo: uBI013_trips_with_next_station_features.parquet, Número de filas después de ingeniería de características: 188709
# Número total de filas después de ingeniería de características: 43030926
# Número total de unidades útiles: 156
